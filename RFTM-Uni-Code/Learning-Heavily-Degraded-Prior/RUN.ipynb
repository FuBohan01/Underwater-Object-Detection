# %%
import sys
sys.path.append('Learning-Heavily-Degraded-Prior/mmdet/')

# %%
# !python Learning-Heavily-Degraded-Prior/tools/train.py Learning-Heavily-Degraded-Prior/configs/rftm/rftm_50.py
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# 2024-02-22 18:40:20,116 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 3090
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.8.r11.8/compiler.31833905_0
# GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# PyTorch: 2.0.0+cu118
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
# ...

# %%
# !python Learning-Heavily-Degraded-Prior/tools/train.py Learning-Heavily-Degraded-Prior/configs/rftm/rftm_50.py
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# 2024-02-25 12:34:28,676 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 3090
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.8.r11.8/compiler.31833905_0
# GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# PyTorch: 2.0.0+cu118
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
# ...

# %%
# !python Learning-Heavily-Degraded-Prior/tools/train.py Learning-Heavily-Degraded-Prior/configs/rftm/rftm_50.py --resume-from work_dirs/rftm_50/latest.pth
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# 2024-03-07 21:49:23,262 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 4090
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.8.r11.8/compiler.31833905_0
# GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# PyTorch: 2.0.0+cu118
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
# ...

# %%
# !python Learning-Heavily-Degraded-Prior/tools/train.py Learning-Heavily-Degraded-Prior/configs/rftm/rftm_50.py --work-dir /root/autodl-tmp/work_dirs_rftm_uni/ \
--resume-from autodl-tmp/work_dirs_rftm_uni/epoch_24.pth
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# 2024-04-02 11:14:50,948 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 4090
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.8.r11.8/compiler.31833905_0
# GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# PyTorch: 2.0.0+cu118
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
# ...

# %%
# !python Learning-Heavily-Degraded-Prior/tools/train.py Learning-Heavily-Degraded-Prior/configs/rftm/rftm_50.py \
--work-dir /root/autodl-tmp/work_dirs_rftm_little_data/
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# 2024-03-29 12:21:52,660 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 4090
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.8.r11.8/compiler.31833905_0
# GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# PyTorch: 2.0.0+cu118
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
# ...

# %% [markdown]
# # 以下为URPC 以上为DUO

# %%
# !python Learning-Heavily-Degraded-Prior/tools/train.py Learning-Heavily-Degraded-Prior/configs/rftm/rftm_50-URPC.py \
--work-dir /root/autodl-tmp/work_dirs_rftm_uni_urpc/
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# 2024-04-03 02:04:32,732 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.10 (default, Jun  4 2021, 15:09:15) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 4090
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.8.r11.8/compiler.31833905_0
# GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# PyTorch: 2.0.0+cu118
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
# ...
